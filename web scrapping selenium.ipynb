# %%
# !pip install selenium

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome(r"C:\Users\user3\Downloads\chromedriver_win32\chromedriver.exe")

# %%
#open naukri page automated chrome browser
driver.get("https://www.naukri.com/")

# %%
#entering designation and location
designation=driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Analyst')

# %%
location=driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input")
location.send_keys('Banglore')

# %%
search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
job_title=[]
job_location=[]
company_name=[]
experience_required=[]

# %%
#scraping job title from given page
title_tags=driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)

# %%
#scraping job location ,company name, job experience
location_tags=driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi location"]')
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)  
    
company_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags[0:10]:
    company=i.text
    company_name.append(company)

# %%
experience_tags=driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi experience"]//span')
for i in experience_tags[0:10]:
    exp=i.text
    experience_required.append(exp)

# %%
print(len(job_title),len(job_location),len(company_name),len(experience_required))
# Out:
# 10 10 10 10

# %%
#creating data frame
df=pd.DataFrame({'job_title':job_title,'job_location':job_location,'company_name':company_name,'Exp_required':experience_required})
df
# Out:
#                                      job_title  \
# 0                                 Data Analyst
# 1  Senior Data Analyst - Data Modeling/Quality
# 2                  Data Analyst - CRM Platform
# 3                          Senior Data Analyst
# 4                          Senior Data Analyst
# 5            Senior Data Analyst - SQL/Tableau
# 6                             Sr. Data Analyst
# 7              Senior Data Analyst - Immediate
# 8                          Senior Data Analyst
# 9                                 Data Analyst
#
#                                         job_location  \
# 0                                Bangalore/Bengaluru
# 1                                Bangalore/Bengaluru
# 2  Kolkata, Mumbai, Hyderabad/Secunderabad, Pune,...
# 3                                Bangalore/Bengaluru
# 4        Hyderabad/Secunderabad, Bangalore/Bengaluru
# 5  Kolkata, Mumbai, Hyderabad/Secunderabad, Pune,...
# 6                                             Remote
# ...

# %% [markdown]
# Q2: Write a python program to scrape data for “Data Scientist” Job position in “Bangalore” location. You
# have to scrape the job-title, job-location, company_name. You have to scrape first 10 jobs data

# %%
driver=webdriver.Chrome(r"C:\Users\user3\Downloads\chromedriver_win32\chromedriver.exe")

# %%
#open naukri page automated chrome browser
driver.get("https://www.naukri.com/")

# %%
designation=driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Scientist')

# %%
location=driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input")
location.send_keys('Banglore')

# %%
search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
job_title=[]
job_location=[]
company_name=[]
experience_required=[]

# %%
#scraping job title from given page
title_tags=driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)

# %%
#scraping job location ,company name, job experience
#scraping job location ,company name, job experience
location_tags=driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi location"]')
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)
    
company_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags[0:10]:
    company=i.text
    company_name.append(company) 
    
experience_tags=driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi experience"]//span')
for i in experience_tags[0:10]:
    exp=i.text
    experience_required.append(exp)

# %%
print(len(job_title),len(job_location),len(company_name),len(experience_required))
# Out:
# 10 10 10 10

# %%
df=pd.DataFrame({'job_title':job_title,'job_location':job_location,'company_name':company_name,'Exp_required':experience_required})
df
# Out:
#                                            job_title  \
# 0                   Assistant Manager - Data Science
# 1                   Analystics & Modeling Specialist
# 2  Hiring For DATA Scientist @ NTT DATA Business ...
# 3                                     Data Scientist
# 4                             General Data Scientist
# 5    Senior Manager II - Data science ( Marketplace)
# 6                              Senior Data Scientist
# 7                                  Lead ML Scientist
# 8                                Data Scientist - II
# 9                              Senior Data Scientist
#
#                                         job_location  \
# 0                  Mumbai, Pune, Bangalore/Bengaluru
# 1  Kolkata, Mumbai, Hyderabad/Secunderabad, Pune,...
# 2  Noida, Hyderabad/Secunderabad, Pune, Gurgaon/G...
# 3              Gurgaon/Gurugram, Bangalore/Bengaluru
# 4                                Bangalore/Bengaluru
# 5                                Bangalore/Bengaluru
# ...

# %% [markdown]
# Q3: In this question you have to scrape data using the filters available on the webpage

# %%
driver=webdriver.Chrome(r"C:\Users\user3\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get("https://www.naukri.com/")

# %%
designation=driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Scientist')

# %%
search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
salary=driver.find_element(By.XPATH,"/html/body/div[1]/div[4]/div/section[1]/div[2]/div[6]/div[2]/div[2]/label/p")
salary.click()

# %%
job_title=[]
job_location=[]
company_name=[]
experience_required=[]

# %%
#scraping job location ,company name, job experience
#scraping job location ,company name, job experience

title_tags=driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title) 

location_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft fs12 lh16 "]')
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)
    
company_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags[0:10]:
    company=i.text
    company_name.append(company) 
    
experience_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft fs12 lh16 "]')
for i in experience_tags[0:10]:
    exp=i.text
    experience_required.append(exp)

# %%
print(len(job_title),len(job_location),len(company_name),len(experience_required))
# Out:
# 10 10 10 10

# %%
df=pd.DataFrame({'job_title':job_title,'job_location':job_location,'company_name':company_name,'Exp_required':experience_required})
df
# Out:
#                                  job_title  \
# 0             Data Scientist/AIML Engineer
# 1                           Data Scientist
# 2                           Data Scientist
# 3                           Data Scientist
# 4                           Data Scientist
# 5                           Data Scientist
# 6                           Data Scientist
# 7  Senior Associate - MSET Support Role QR
# 8                     data science analyst
# 9          DigitalBCG GAMMA Data Scientist
#
#                                         job_location  \
# 0                                            0-2 Yrs
# 1                            2,50,000 - 6,00,000 PA.
# 2  Mumbai, Hyderabad/Secunderabad, Bangalore/Beng...
# 3                                           8-10 Yrs
# 4                            3,00,000 - 4,50,000 PA.
# 5                 Noida, Nagpur, Bangalore/Bengaluru
# 6                                            2-7 Yrs
# 7                                      Not disclosed
# ...

# %% [markdown]
# Q4: Scrape data of first 100 sunglasses listings on flipkart.com. You have to scrape four attributes:
# 1. Brand
# 2. Product Description
# 3. Price

# %%
driver=webdriver.Chrome(r"C:\Users\user3\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get("https://www.flipkart.com/")

# %%
product=driver.find_element(By.CLASS_NAME,"_3704LK")
product.send_keys('sun glasses')

# %%
search=driver.find_element(By.CLASS_NAME,"_34RNph")
search.click()

# %%
brands=[]
product_description=[]
rates=[]

# %%
brand_tags=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in brand_tags[0:100]:
    brand=i.text
    brands.append(brand)

# %%
print(len(brands))
# Out:
# 40

# %%
description_tags=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
for i in description_tags[0:100]:
    description=i.text
    product_description.append(description)

# %%
print(len(product_description))
# Out:
# 40

# %%
rate_tags=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
for i in rate_tags[0:100]:
    rate=i.text
    rates.append(rate)

# %%
print(len(rates))
# Out:
# 40

# %%
print(len(brands),len(product_description),len(rates))
# Out:
# 40 40 40

# %%
df=pd.DataFrame({'brands':brands,'rates':product_description,'product_description':rates,})
df
# Out:
#             brands                                              rates  \
# 0    VINCENT CHASE     Polarized, UV Protection Round Sunglasses (51)
# 1    VINCENT CHASE  by Lenskart Polarized, UV Protection Retro Squ...
# 2         Fastrack      UV Protection Wayfarer Sunglasses (Free Size)
# 3   ROZZETTA CRAFT  UV Protection, Gradient Rectangular Sunglasses...
# 4           PIRASO           UV Protection Over-sized Sunglasses (65)
# 5   ROZZETTA CRAFT  UV Protection, Gradient Rectangular Sunglasses...
# 6    VINCENT CHASE  by Lenskart Polarized, UV Protection Retro Squ...
# 7    VINCENT CHASE     Polarized, UV Protection Round Sunglasses (50)
# 8   ROZZETTA CRAFT  UV Protection Retro Square Sunglasses (Free Size)
# 9        ROYAL SON              Polarized Rectangular Sunglasses (60)
# 10   VINCENT CHASE  by Lenskart Polarized, UV Protection Wayfarer ...
# 11   VINCENT CHASE          UV Protection Rectangular Sunglasses (50)
# ...

# %%
brands=[]
product_description=[]
rates=[]

# %%
brand_tags=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in brand_tags[0:100]:
    brand=i.text
    brands.append(brand)
    
    
description_tags=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
for i in description_tags[0:100]:
    description=i.text
    product_description.append(description)  
    
    
rate_tags=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
for i in rate_tags[0:100]:
    rate=i.text
    rates.append(rate)

# %%
print(len(brands),len(product_description),len(rates))
# Out:
# 40 40 40

# %%
df=pd.DataFrame({'brands':brands,'rates':rates,'product_description':product_description,})
df
# Out:
#             brands   rates                                product_description
# 0    VINCENT CHASE  ₹1,128     Polarized, UV Protection Round Sunglasses (51)
# 1    VINCENT CHASE  ₹1,049  by Lenskart Polarized, UV Protection Retro Squ...
# 2         Fastrack    ₹799      UV Protection Wayfarer Sunglasses (Free Size)
# 3   ROZZETTA CRAFT    ₹319  UV Protection, Gradient Rectangular Sunglasses...
# 4           PIRASO    ₹383           UV Protection Over-sized Sunglasses (65)
# 5   ROZZETTA CRAFT    ₹359  UV Protection, Gradient Rectangular Sunglasses...
# 6    VINCENT CHASE    ₹901  by Lenskart Polarized, UV Protection Retro Squ...
# 7    VINCENT CHASE  ₹1,049     Polarized, UV Protection Round Sunglasses (50)
# 8   ROZZETTA CRAFT    ₹449  UV Protection Retro Square Sunglasses (Free Size)
# 9        ROYAL SON    ₹559              Polarized Rectangular Sunglasses (60)
# 10   VINCENT CHASE    ₹711  by Lenskart Polarized, UV Protection Wayfarer ...
# ...

# %%
brands=[]
product_description=[]
rates=[]

# %%
brand_tags=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in brand_tags[0:20]:
    brand=i.text
    brands.append(brand)
    
    
description_tags=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
for i in description_tags[0:20]:
    description=i.text
    product_description.append(description)  
    
    
rate_tags=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
for i in rate_tags[0:20]:
    rate=i.text
    rates.append(rate)

# %%
df=pd.DataFrame({'brands':brands,'rates':rates,'product_description':product_description,})
df
# Out:
#             brands   rates                                product_description
# 0    VINCENT CHASE  ₹1,128     Polarized, UV Protection Round Sunglasses (51)
# 1    VINCENT CHASE  ₹1,049  by Lenskart Polarized, UV Protection Retro Squ...
# 2         Fastrack    ₹799      UV Protection Wayfarer Sunglasses (Free Size)
# 3   ROZZETTA CRAFT    ₹319  UV Protection, Gradient Rectangular Sunglasses...
# 4           PIRASO    ₹383           UV Protection Over-sized Sunglasses (65)
# 5   ROZZETTA CRAFT    ₹359  UV Protection, Gradient Rectangular Sunglasses...
# 6    VINCENT CHASE    ₹901  by Lenskart Polarized, UV Protection Retro Squ...
# 7    VINCENT CHASE  ₹1,049     Polarized, UV Protection Round Sunglasses (50)
# 8   ROZZETTA CRAFT    ₹449  UV Protection Retro Square Sunglasses (Free Size)
# 9        ROYAL SON    ₹559              Polarized Rectangular Sunglasses (60)
# 10   VINCENT CHASE    ₹711  by Lenskart Polarized, UV Protection Wayfarer ...
# ...

# %% [markdown]
# 5: Scrape 100 reviews data from flipkart.com for iphone11 phone.

# %%
driver=webdriver.Chrome(r"C:\Users\user3\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get("https://www.flipkart.com/")

# %%
product=driver.find_element(By.CLASS_NAME,"_3704LK")
product.send_keys('iphone11')

# %%
search=driver.find_element(By.CLASS_NAME,"L0Z3Pu")
search.click()

# %%
ratings=[]
review_summary=[]
full_review=[]

# %%
driver.get("https://www.flipkart.com/apple-iphone-11-black-128-gb/p/itm8244e8d955aba?pid=MOBFWQ6BKRYBP5X8&lid=LSTMOBFWQ6BKRYBP5X8X0KYUG&marketplace=FLIPKART&q=iphone11&store=tyy%2F4io&srno=s_1_5&otracker=search&otracker1=search&fm=organic&iid=14b3d385-6cd3-41d2-8b5e-24cb8bfc383c.MOBFWQ6BKRYBP5X8.SEARCH&ppt=hp&ppn=homepage&ssid=8jaels34lc0000001663494105657&qH=d6db477051465f9a")

# %%
rating_tags=driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')
for i in rating_tags[0:6]:
    rating=i.text
    ratings.append(rating)

# %%
print(len(ratings))
# Out:
# 6

# %%
 
    
reviewt_tags=driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')
for i in reviewt_tags[0:6]:
    reviewt=i.text
    review_summary.append(reviewt)
    
    
review_tags=driver.find_elements(By.XPATH,'//div[@class]')
for i in review_tags[0:6]:
    rate=i.text
    full_review.append(review_tags)

# %%
print(len(ratings),len(review_summary),len(full_review))
# Out:
# 6 6 6

# %%
df=pd.DataFrame({'ratings':ratings,'review_summary':review_summary,'full_review':full_review})
df
# Out:
#   ratings       review_summary  \
# 0       5       Simply awesome
# 1       5     Perfect product!
# 2       5  Best in the market!
# 3
# 4
# 5
#
#                                          full_review
# 0  [<selenium.webdriver.remote.webelement.WebElem...
# 1  [<selenium.webdriver.remote.webelement.WebElem...
# 2  [<selenium.webdriver.remote.webelement.WebElem...
# 3  [<selenium.webdriver.remote.webelement.WebElem...
# 4  [<selenium.webdriver.remote.webelement.WebElem...
# 5  [<selenium.webdriver.remote.webelement.WebElem...

# %%
ratings=[]
review_summary=[]
full_review=[]

# %%
rating_tags=driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')
for i in rating_tags[0:6]:
    rating=i.text
    ratings.append(rating) 
    
reviewt_tags=driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')
for i in reviewt_tags[0:6]:
    reviewt=i.text
    review_summary.append(reviewt)
    
    
review=driver.find_elements(By.XPATH,'//div[@class]')
for i in review_tags[0:6]:
    rate=i.text
    full_review.append(review)

# %%
print(len(ratings),len(review_summary),len(full_review))
# Out:
# 12 12 12

# %%
df=pd.DataFrame({'ratings':ratings,'review_summary':review_summary,'full_review':full_review})
df
# Out:
#    ratings      review_summary  \
# 0        4         Good choice
# 1        5  Highly recommended
# 2        5    Perfect product!
# 3        5    Perfect product!
# 4        5    Perfect product!
# 5        5  Highly recommended
# 6        4         Good choice
# 7        5  Highly recommended
# 8        5    Perfect product!
# 9        5    Perfect product!
# 10       5    Perfect product!
# 11       5  Highly recommended
#
#                                           full_review
# 0   [<selenium.webdriver.remote.webelement.WebElem...
# 1   [<selenium.webdriver.remote.webelement.WebElem...
# 2   [<selenium.webdriver.remote.webelement.WebElem...
# 3   [<selenium.webdriver.remote.webelement.WebElem...
# 4   [<selenium.webdriver.remote.webelement.WebElem...
# 5   [<selenium.webdriver.remote.webelement.WebElem...
# 6   [<selenium.webdriver.remote.webelement.WebElem...
# 7   [<selenium.webdriver.remote.webelement.WebElem...
# 8   [<selenium.webdriver.remote.webelement.WebElem...
# ...

# %%
driver=webdriver.Chrome(r"C:\Users\user3\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get("https://www.flipkart.com/")

# %%
brands=[]
product_description=[]
price=[]

# %%
product=driver.find_element(By.CLASS_NAME,"_3704LK")
product.send_keys('sneakers')

# %%
search=driver.find_element(By.CLASS_NAME,"_34RNph")
search.click()

# %%
brand_tags=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in brand_tags[0:38]:
    brand=i.text
    brands.append(brand)
    
description_tags=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
for i in description_tags[0:38]:
    description=i.text
    product_description.append(description)  
    
    
rate_tags=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
for i in rate_tags[0:38]:
    rate=i.text
    price.append(rate)

# %%
print(len(brands),len(product_description),len(price))
# Out:
# 38 38 38

# %%
df=pd.DataFrame({'brands':brands,'price':price,'product_description':product_description,})
df
# Out:
#             brands   price                                product_description
# 0          Numenzo    ₹559                                   Sneakers For Men
# 1         RapidBox    ₹501                                   Sneakers For Men
# 2           BRUTON    ₹236      Modern Trendy Sneakers Shoes Sneakers For Men
# 3            BIRDE    ₹299      Premium Casual Shoes for Men Sneakers For Men
# 4           BRUTON    ₹179  Lightweight Pack Of 1 Trendy Sneakers Sneakers...
# 5               TR    ₹364                                   Sneakers For Men
# 6           Labbin    ₹399                                   Sneakers For Men
# 7           Rzisbo    ₹412                                   Sneakers For Men
# 8               TR    ₹295                      Casual Shoes Sneakers For Men
# 9            BIRDE    ₹199                                   Sneakers For Men
# 10        Magnolia    ₹299                                   Sneakers For Men
# ...

# %%
brands=[]
product_description=[]
price=[]

# %%
brand_tags=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in brand_tags[0:36]:
    brand=i.text
    brands.append(brand)
    
    
description_tags=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
for i in description_tags[0:36]:
    description=i.text
    product_description.append(description)  
    
    
rate_tags=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
for i in rate_tags[0:36]:
    rate=i.text
    price.append(rate)

# %%
print(len(brands),len(product_description),len(price))
# Out:
# 36 36 36

# %%
df=pd.DataFrame({'brands':brands,'price':price,'product_description':product_description,})
df
# Out:
#             brands   price                                product_description
# 0          Numenzo    ₹559                                   Sneakers For Men
# 1         RapidBox    ₹501                                   Sneakers For Men
# 2           BRUTON    ₹236      Modern Trendy Sneakers Shoes Sneakers For Men
# 3            BIRDE    ₹299      Premium Casual Shoes for Men Sneakers For Men
# 4           BRUTON    ₹179  Lightweight Pack Of 1 Trendy Sneakers Sneakers...
# 5               TR    ₹364                                   Sneakers For Men
# 6           Labbin    ₹399                                   Sneakers For Men
# 7           Rzisbo    ₹412                                   Sneakers For Men
# 8               TR    ₹295                      Casual Shoes Sneakers For Men
# 9            BIRDE    ₹199                                   Sneakers For Men
# 10        Magnolia    ₹299                                   Sneakers For Men
# ...

# %%
driver=webdriver.Chrome(r"C:\Users\user3\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get("https://www.flipkart.com/")

# %%
product=driver.find_element(By.CLASS_NAME,"_3704LK")
product.send_keys('sneakers')

# %%
search=driver.find_element(By.CLASS_NAME,"_34RNph")
search.click()

# %%
brands=[]
product_description=[]
price=[]

# %%
brand_tags=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in brand_tags[0:32]:
    brand=i.text
    brands.append(brand)
    
    
description_tags=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
for i in description_tags[0:32]:
    description=i.text
    product_description.append(description)  
    
    
rate_tags=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
for i in rate_tags[0:32]:
    rate=i.text
    price.append(rate)

# %%
print(len(brands),len(product_description),len(price))
# Out:
# 32 32 32

# %%
df=pd.DataFrame({'brands':brands,'price':price,'product_description':product_description,})
df
# Out:
#                  brands    price  \
# 0                 Echor     ₹431
# 1                 asics   ₹5,999
# 2                Labbin     ₹399
# 3                Bonexy     ₹699
# 4              Magnolia     ₹299
# 5                 Xtoon     ₹424
# 6                Kraasa     ₹428
# 7                Rzisbo     ₹439
# 8                 Sparx     ₹619
# 9   World Wear Footwear     ₹249
# 10                Echor     ₹559
# 11                asics   ₹5,129
# 12              Dizzler     ₹479
# 13               Layasa     ₹473
# 14          bacca bucci   ₹1,199
# 15             LE GREEM     ₹449
# 16                 PUMA   ₹3,149
# 17                asics   ₹4,749
# 18             RapidBox     ₹549
# 19             ASTEROID     ₹449
# 20               Shozie     ₹379
# 21                asics  ₹10,449
# 22               Kraasa     ₹468
# 23                 Hida     ₹424
# 24          Scull Wings     ₹494
# 25                 PUMA   ₹2,192
# 26               Layasa     ₹399
# ...

# %% [markdown]
# Q7: Go to the link - https://www.myntra.com/shoes
# Set second Price filter and Color filter to “Black”, as shown in the below image.
# And then scrape First 100 shoes data you get. The data should include “Brand” of the shoes , Short Shoe
# description, price of the shoe as shown in the below image

# %%
driver=webdriver.Chrome(r"C:\Users\user3\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get("http://www.myntra.com/shoes")

# %%
product=driver.find_elements(By.XPATH,'//label[@class="common-customCheckbox vertical-filters-label"]')

# %%
price=driver.find_element(By.XPATH,"/html/body/div[2]/div/div[1]/main/div[3]/div[1]/section/div/div[5]/ul/li[2]/label")
price.click()

# %%
color=driver.find_element(By.XPATH,"/html/body/div[2]/div/div[1]/main/div[3]/div[1]/section/div/div[6]/ul/li[1]/label")
color.click()

# %%
brands=[]
product_description=[]
price=[]

# %%
brand_tags=driver.find_elements(By.XPATH,'//h3[@class="product-brand"]')
for i in brand_tags[0:34]:
    brand=i.text
    brands.append(brand)
    
    
description_tags=driver.find_elements(By.XPATH,'//h4[@class="product-product"]')
for i in description_tags[0:34]:
    description=i.text
    product_description.append(description)  
    
    
rate_tags=driver.find_elements(By.XPATH,'//span[@class="product-discountedPrice"]')
for i in rate_tags[0:34]:
    rate=i.text
    price.append(rate)

# %%
print(len(brands),len(product_description),len(price))
# Out:
# 34 34 34

# %%
df=pd.DataFrame({'brands':brands,'price':price,'product_description':product_description,})
df
# Out:
#               brands      price                        product_description
# 0               Nike  Rs. 13295               Men React Infinity 3 Running
# 1       UNDER ARMOUR  Rs. 10799              Unisex Curry Basketball Shoes
# 2   ADIDAS Originals   Rs. 9499              Men Leather Niteball Sneakers
# 3           Skechers   Rs. 9099                          Men Walking Shoes
# 4             ADIDAS   Rs. 7199             Men Alphabounce 1Running Shoes
# 5               Nike  Rs. 11699             Men JORDAN LOW Basketball Shoe
# 6   ADIDAS Originals  Rs. 11699                   Men Retropy F90 Sneakers
# 7               Puma  Rs. 10199               Eternity Nitro Running Shoes
# 8             ADIDAS   Rs. 8450                  Women X9000 H.RDY Running
# 9       UNDER ARMOUR  Rs. 10499                Men Vantage 2 Running Shoes
# 10  ADIDAS Originals   Rs. 9210             Men Colorblocked Ozrah Sneaker
# ...

# %%
brands=[]
product_description=[]
price=[]

# %%
brand_tags=driver.find_elements(By.XPATH,'//h3[@class="product-brand"]')
for i in brand_tags[0:31]:
    brand=i.text
    brands.append(brand)
    
    
description_tags=driver.find_elements(By.XPATH,'//h4[@class="product-product"]')
for i in description_tags[0:31]:
    description=i.text
    product_description.append(description)  
    
    
rate_tags=driver.find_elements(By.XPATH,'//span[@class="product-discountedPrice"]')
for i in rate_tags[0:31]:
    rate=i.text
    price.append(rate)

# %%
print(len(brands),len(product_description),len(price))
# Out:
# 31 31 31

# %%
df=pd.DataFrame({'brands':brands,'price':price,'product_description':product_description,})
df
# Out:
#               brands      price             product_description
# 0   ADIDAS Originals  Rs. 10799        Men ZX 22 BOOST Sneakers
# 1           Skechers   Rs. 8999       Men GO WALK - TERRA Shoes
# 2             ADIDAS  Rs. 10799      Men Response Super 3.0 Run
# 3             ADIDAS   Rs. 8499     Men Adizero Adios 7 Running
# 4              ASICS  Rs. 11049         Evoride 3 Running Shoes
# 5   ADIDAS Originals   Rs. 7199        Men Retropy F90 Sneakers
# 6     ROSSO BRUNELLO   Rs. 7199    Men Textured Leather Loafers
# 7           Skechers   Rs. 7199     Men Sky Vault Walking Shoes
# 8              Ruosh   Rs. 9499             Men Leather Loafers
# 9    PUMA Motorsport  Rs. 11305   Unisex Ferrari Speed Sneakers
# 10      Calvin Klein  Rs. 12599            Men Leather Sneakers
# 11            ADIDAS   Rs. 9899       Men CourtJam Control Clay
# 12              ALDO  Rs. 12599       Men Leather Formal Derbys
# 13          Columbia   Rs. 8799               Men Running Shoes
# ...

# %%
brands=[]
product_description=[]
price=[]

# %%
brand_tags=driver.find_elements(By.XPATH,'//h3[@class="product-brand"]')
for i in brand_tags[0:34]:
    brand=i.text
    brands.append(brand)
    
    
description_tags=driver.find_elements(By.XPATH,'//h4[@class="product-product"]')
for i in description_tags[0:34]:
    description=i.text
    product_description.append(description)  
    
    
rate_tags=driver.find_elements(By.XPATH,'//div[@class="product-price"]')
for i in rate_tags[0:34]:
    rate=i.text
    price.append(rate)

# %%
print(len(brands),len(product_description),len(price))
# Out:
# 34 34 34

# %%
df=pd.DataFrame({'brands':brands,'price':price,'product_description':product_description,})
df
# Out:
#               brands                        price  \
# 0       Sole To Soul    Rs. 7565Rs. 8900(15% OFF)
# 1               Geox                    Rs. 11990
# 2     Louis Philippe                     Rs. 9999
# 3   ADIDAS Originals                     Rs. 9999
# 4               Geox                     Rs. 9990
# 5           Skechers                     Rs. 7499
# 6          J.FONTINI                     Rs. 7490
# 7           Skechers                     Rs. 8999
# 8             Kenkoh                     Rs. 8575
# 9            fitflop                     Rs. 7499
# 10              Puma                     Rs. 8999
# 11          Columbia                     Rs. 7999
# 12              ALDO                    Rs. 10999
# 13              ALDO                    Rs. 12999
# 14              Puma    Rs. 8499Rs. 9999(15% OFF)
# 15              ALDO                    Rs. 10999
# 16            ADIDAS  Rs. 11199Rs. 13999(20% OFF)
# 17              ALDO                    Rs. 13999
# ...

# %% [markdown]
# Q8: Go to webpage https://www.amazon.in/
# Enter “Laptop” in the search field and then click the search icon

# %%
driver=webdriver.Chrome(r"C:\Users\user3\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get("https://www.amazon.in/")

# %%
product=driver.find_element(By.CLASS_NAME,"_3704LK")
product.send_keys('laptop')

# %%
search=driver.find_element(By.CLASS_NAME,"nav-search-submit-text nav-sprite nav-progressive-attribute")
search.click()

# %%
brand=driver.find_element(By.XPATH,"/html/body/div[1]/div[2]/div[1]/div[2]/div/div[3]/span/div[1]/div/div/div[6]/ul[5]/li[10]/span/a/span")
brand.click()

# %%
Title=[]
Ratings=[]
price=[]

# %%
brand_tags=driver.find_elements(By.XPATH,'//span[@class="a-size-medium a-color-base a-text-normal"]')
for i in brand_tags[0:9]:
    brand=i.text
    Title.append(brand)
    
    
description_tags=driver.find_elements(By.XPATH,'//i[@class="a-icon a-icon-star-small a-star-small-4-5 aok-align-bottom"]')
for i in description_tags[0:9]:
    description=i.text
    Ratings.append(description)  
    
    
rate_tags=driver.find_elements(By.XPATH,'//span[@class="a-price-whole"]')
for i in rate_tags[0:9]:
    rate=i.text
    price.append(rate)

# %%
print(len(Title),len(Ratings),len(price))
# Out:
# 9 9 9

# %%
df=pd.DataFrame({'Title':Title,'price':price,'Ratings':Ratings,})
df
# Out:
#                                                Title     price Ratings
# 0  LG Gram Intel Evo 11th Gen Core i7 17"(43cm)Ul...    94,999
# 1  Acer Spin 5 Professional Laptop with Alexa Bui...  1,24,490
# 2  Lenovo ThinkBook 15 Intel 11th Gen Core i7 15....    80,990
# 3  Lenovo IdeaPad Slim 5 Intel Core i7 12th Gen 1...    82,990
# 4  Hp Pavilion X360 11Th Gen Intel Core I7 14 Inc...    82,990
# 5  HP Pavilion x360 11th Gen Intel Core i7 14 inc...    81,990
# 6  ASUS Zenbook 13 OLED, 13.3-inch (33.78 cms) FH...    79,990
# 7  Fujitsu UH-X 11th Gen Intel Core i7 13.3" FHD ...    99,990
# 8  ASUS Vivobook 15, 15.6-inch (39.62 cms) FHD, I...    57,890

# %% [markdown]
# Q9: Write a python program to scrape data for first 10 job results for Data Scientist Designation in Noida
# location. You have to scrape company name, No. of days ago when job was posted, Rating of the company.
# This task will be done in following steps:
# 1. First get the webpage https://www.ambitionbox.com/
# 2. Click on the Job option as shown in the imag

# %%
driver=webdriver.Chrome(r"C:\Users\user3\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get("https://www.ambitionbox.com/")

# %%
search=driver.find_element(By.CLASS_NAME,"_34RNph")
search.click()
